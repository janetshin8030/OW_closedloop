# %%
import numpy as np
import pandas as pd
import mne
import math
import os

# %%
base_dir = r"C:\Users\jshin\OW_closedloopLIFU\eeg_windows\scope\demo1119"
theta_df = []
# List all CSV files in the folder
csv_files = [f for f in os.listdir(base_dir) if f.endswith(".csv")]

# Sort by creation time (oldest first)
csv_files.sort(key=lambda f: os.path.getctime(os.path.join(base_dir, f)))

# Pick the first one
first_file = csv_files[1]

for idx, window in enumerate(csv_files):
    path = os.path.join(base_dir, csv_files[idx])
    idx_df = pd.read_csv(path) 
    theta_df.append(idx_df)
theta_df[0]
# Out:
#            LSL Time           Raw  Theta Bandpass      Power  Moving Average  \
# 0     555922.904871  41915.042969       -4.576506  20.944408       30.587301
# 1     555922.907865  42614.437500       -3.171508  10.058461       30.782095
# 2     555922.908615  43155.125000       -1.648960   2.719070       30.809942
# 3     555922.913691  42631.773438       -0.037902   0.001437       30.749767
# 4     555922.916780  41958.644531        1.629154   2.654142       30.696823
# ...             ...           ...             ...        ...             ...
# 1743  555929.863629  43388.679688       -0.235519   0.055469        1.015679
# 1744  555929.877136  43243.917969       -0.382112   0.146010        1.011544
# 1745  555929.878636  41329.125000       -0.517745   0.268060        1.012415
# 1746  555929.879059  42176.394531       -0.641106   0.411016        1.018479
# 1747  555929.879405  43311.429688       -0.751538   0.564809        1.029255
#
#        Z-score      Hold  Trigger Channel  offline z-score    median  \
# 0     6.762512  5.660573        -0.179967         5.660573  1.552163
# 1     6.809114  5.660573        -0.216764         5.660573  1.552163
# 2     6.815776  5.660573        -0.122998         5.660573  1.552163
# 3     6.801380  5.660573         0.043426         5.660573  1.552163
# 4     6.788714  5.660573         0.202937         5.660573  1.552163
# ...        ...       ...              ...              ...       ...
# 1743 -0.312039 -0.302823        15.600492        -0.302823  0.948223
# 1744 -0.313028 -0.312819       -20.565088        -0.312819  0.937858
# 1745 -0.312819 -0.312819       -28.791409        -0.312819  0.937858
# 1746 -0.311369 -0.312819         3.099386        -0.312819  0.937858
# 1747 -0.308791 -0.312819        30.689001        -0.312819  0.937858
#
#            mad  LIFU     t_rel  idx
# 0     5.660573   0.0 -1.986978    0
# 1     5.660573   0.0 -1.983985    0
# 2     5.660573   0.0 -1.983234    0
# 3     5.660573   0.0 -1.978158    0
# 4     5.660573   0.0 -1.975069    0
# ...        ...   ...       ...  ...
# 1743 -0.302823   0.0  4.971779    0
# 1744  1.193482   0.0  4.985287    0
# 1745 -0.312819   0.0  4.986786    0
# 1746 -0.312819   0.0  4.987210    0
# 1747 -0.312819   0.0  4.987555    0
#
# [1748 rows x 14 columns]

# %%
lifu_markers = pd.read_csv("lifu_markers_1_2back_demo1119.csv")
lifu_on_df = lifu_markers[lifu_markers["marker"] == "LIFU_ON"]
lifu_on = np.array(lifu_on_df["LSL_timestamp"])
lifu_on
# Out:
# array([555924.8918494, 555944.9328929, 556030.6534903])

# %%
#finding baseline median and mean
medians = []
mads = []
tol = 0.002

for idx, event in enumerate(lifu_on):
    df = theta_df[idx]
    diff = np.abs(df["LSL Time"].values - event)
    i = np.argmin(diff)
    row = df.iloc[i]
    median = row["median"]
    mad = row["mad"]
    medians.append(median)
    mads.append(mad)
print(f"medians = {medians}")
print(f"mads = {mads}")
# Out:
# medians = [1.7600671648979187, -0.103686649352312, -0.0468030273914337]
# mads = [1.6612875328788757, 0.3194501080939769, 1.7109483480453491]

# %%
pre = 2
post = 5
windows = []
for idx, event in enumerate(event_times): 
    mask = (raw['Time'] >= (event - pre)) & (raw['Time'] <= (event + post))
    window_df = raw.loc[mask].copy()
    window_df["t_rel"] = window_df["Time"] - event 
    window_df["idx"] = idx
    windows.append(window_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[187], line 5
#       3 windows = []
#       4 for idx, event in enumerate(event_times):
# ----> 5     mask = (raw['Time'] >= (event - pre)) & (raw['Time'] <= (event + post))
#       6     window_df = raw.loc[mask].copy()
#       7     window_df["t_rel"] = window_df["Time"] - event
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\mne\io\base.py:867, in BaseRaw.__getitem__(self, item)
#     831 def __getitem__(self, item):
#     832     """Get raw data and times.
#     833
#     834     Parameters
#    (...)
#     865
#     866     """  # noqa: E501
# --> 867     return self._getitem(item)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\mne\io\base.py:870, in BaseRaw._getitem(self, item, return_times)
#     869 def _getitem(self, item, return_times=True):
# --> 870     sel, start, stop = self._parse_get_set_params(item)
#     871     if self.preload:
#     872         data = self._data[sel, start:stop]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\mne\io\base.py:800, in BaseRaw._parse_get_set_params(self, item)
#     795 if len(item) != 2:  # should be channels and time instants
#     796     raise RuntimeError(
#     797         "Unable to access raw data (need both channels and time)"
#     798     )
# --> 800 sel = _picks_to_idx(self.info, item[0])
#     802 if isinstance(item[1], slice):
#     803     time_slice = item[1]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\mne\_fiff\pick.py:1257, in _picks_to_idx(info, picks, none, exclude, allow_empty, with_ref_meg, return_kind, picks_on)
#    1255     raise ValueError(f"picks must be 1D, got {picks.ndim}D")
#    1256 if picks.dtype.char in ("S", "U"):
# -> 1257     picks = _picks_str_to_idx(
#    1258         info,
#    1259         picks,
#    1260         exclude,
#    1261         with_ref_meg,
#    1262         return_kind,
#    1263         extra_repr,
#    1264         allow_empty,
#    1265         orig_picks,
#    1266     )
#    1267     if return_kind:
#    1268         picked_ch_type_or_generic = picks[1]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\mne\_fiff\pick.py:1394, in _picks_str_to_idx(info, picks, exclude, with_ref_meg, return_kind, extra_repr, allow_empty, orig_picks)
#    1392 if sum(any_found) == 0:
#    1393     if not allow_empty:
# -> 1394         raise ValueError(
#    1395             f"picks ({repr(orig_picks) + extra_repr}) could not be interpreted as "
#    1396             f'channel names (no channel "{bad_names}"), channel types (no type'
#    1397             f' "{bad_type}" present), or a generic type (just "all" or "data")'
#    1398         )
#    1399     picks = np.array([], int)
#    1400 elif sum(any_found) > 1:
#
# ValueError: picks ('Time') could not be interpreted as channel names (no channel "['Time']"), channel types (no type "Time" present), or a generic type (just "all" or "data")

# %%
windows_df = pd.concat(windows, ignore_index=True)
windows_df_0 = windows_df[windows_df['idx']==0]
windows_df_0

# %%
mask = merged_df[
