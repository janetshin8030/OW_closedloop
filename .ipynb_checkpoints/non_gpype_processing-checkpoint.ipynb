# %%
import numpy as np
import pandas as pd
import mne
import math

# %%
offline
# Out:
#           Time           Ch01           Ch02           Ch03           Ch04  \
# 0        0.000  199999.968750  199999.968750  199999.968750  199999.968750
# 1        0.004  199999.968750  199999.968750  199999.968750  199999.968750
# 2        0.008  199999.968750  199999.968750  199999.968750  199999.968750
# 3        0.012  199999.968750  199999.968750  199999.968750  199999.968750
# 4        0.016  199999.968750  199999.968750  199999.968750  199999.968750
# ...        ...            ...            ...            ...            ...
# 25034  100.136   14888.002930   -3747.392090   55157.781250  163615.718750
# 25035  100.140   15186.287109   -3367.495605   55286.488281  164000.343750
# 25036  100.144   15326.668945   -2985.978027   55725.675781  165823.828125
# 25037  100.148   15149.643555   -3179.764893   55733.761719  165974.703125
# 25038  100.152       0.000000       0.000000       0.000000       0.000000
#
#                 Ch05          Ch06           Ch07        Ch08
# 0      199999.968750  199999.96875  199999.968750  170.707718
# 1      199999.968750  199999.96875  199999.968750  166.654617
# 2      199999.968750  199999.96875  199999.968750  164.127365
# 3      199999.968750  199999.96875  199999.968750  164.890305
# 4      199999.968750  199999.96875  199999.968750  162.744553
# ...              ...           ...            ...         ...
# 25034    5616.928223  199999.96875  -21550.011719  425.124207
# 25035    4870.225098  199999.96875  -21529.843750  421.381042
# 25036    3554.225342  199999.96875  -21872.593750  422.739990
# 25037    3813.338623  199999.96875  -21958.806641  422.096283
# 25038       0.000000       0.00000       0.000000    0.000000
#
# [25039 rows x 9 columns]

# %%
offline = pd.read_csv("thetaEEG_full_2back_-1580742246_20260616_152430.csv")
trigger_channel = offline[[" Ch08", "Time"]]
trigger_channel = pd.DataFrame(trigger_channel)
trigger_channel
# Out:
#              Ch08     Time
# 0      170.707718    0.000
# 1      166.654617    0.004
# 2      164.127365    0.008
# 3      164.890305    0.012
# 4      162.744553    0.016
# ...           ...      ...
# 25034  425.124207  100.136
# 25035  421.381042  100.140
# 25036  422.739990  100.144
# 25037  422.096283  100.148
# 25038    0.000000  100.152
#
# [25039 rows x 2 columns]

# %%
lifu_on_ts = np.array([313249.3567498, 313256.5596819, 313263.7622901, 313271.1735891,313277.7814648, 313284.8678493])
lifu_on_ts
# Out:
# array([313249.3567498, 313256.5596819, 313263.7622901, 313271.1735891,
#        313277.7814648, 313284.8678493])

# %%
pre = 1
post = 0
windows = []
event = np.array([66.1, 73.3, 80.5, 87.9, 94.5])

for idx, ev in enumerate(event):
    mask = (
        (trigger_channel['Time'] >= ev - pre) &
        (trigger_channel['Time'] <= ev + post)
    )
    
    window_df = trigger_channel.loc[mask].copy()
    window_df["t_rel"] = window_df["Time"] - ev
    window_df["idx"] = idx
    windows.append(window_df)


# for idx, event in enumerate(lifu_on_ts):
#     mask = (
#         (trigger_channel['Time'] >= (event - pre)) &
#         (trigger_channel['Time'] <= (event + post))
#     )
    
#     window_df = trigger_channel.loc[mask].copy()
#     window_df["t_rel"] = window_df["Time"] - event
#     window_df["idx"] = idx
#     windows.append(window_df)

# %%
windows[0]
# Out:
#              Ch08    Time  t_rel  idx
# 16025  350.379974  64.100 -2.000    0
# 16026  351.977386  64.104 -1.996    0
# 16027  350.666107  64.108 -1.992    0
# 16028  350.284607  64.112 -1.988    0
# 16029  350.856842  64.116 -1.984    0
# ...           ...     ...    ...  ...
# 17771  376.606049  71.084  4.984    0
# 17772  379.586273  71.088  4.988    0
# 17773  380.039246  71.092  4.992    0
# 17774  377.392761  71.096  4.996    0
# 17775  378.608734  71.100  5.000    0
#
# [1751 rows x 4 columns]

# %%
pre = 2
post = 5
windows = []
for idx, event in enumerate(event_times): 
    mask = (raw['Time'] >= (event - pre)) & (raw['Time'] <= (event + post))
    window_df = raw.loc[mask].copy()
    window_df["t_rel"] = window_df["Time"] - event 
    window_df["idx"] = idx
    windows.append(window_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[187], line 5
#       3 windows = []
#       4 for idx, event in enumerate(event_times):
# ----> 5     mask = (raw['Time'] >= (event - pre)) & (raw['Time'] <= (event + post))
#       6     window_df = raw.loc[mask].copy()
#       7     window_df["t_rel"] = window_df["Time"] - event
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\mne\io\base.py:867, in BaseRaw.__getitem__(self, item)
#     831 def __getitem__(self, item):
#     832     """Get raw data and times.
#     833
#     834     Parameters
#    (...)
#     865
#     866     """  # noqa: E501
# --> 867     return self._getitem(item)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\mne\io\base.py:870, in BaseRaw._getitem(self, item, return_times)
#     869 def _getitem(self, item, return_times=True):
# --> 870     sel, start, stop = self._parse_get_set_params(item)
#     871     if self.preload:
#     872         data = self._data[sel, start:stop]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\mne\io\base.py:800, in BaseRaw._parse_get_set_params(self, item)
#     795 if len(item) != 2:  # should be channels and time instants
#     796     raise RuntimeError(
#     797         "Unable to access raw data (need both channels and time)"
#     798     )
# --> 800 sel = _picks_to_idx(self.info, item[0])
#     802 if isinstance(item[1], slice):
#     803     time_slice = item[1]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\mne\_fiff\pick.py:1257, in _picks_to_idx(info, picks, none, exclude, allow_empty, with_ref_meg, return_kind, picks_on)
#    1255     raise ValueError(f"picks must be 1D, got {picks.ndim}D")
#    1256 if picks.dtype.char in ("S", "U"):
# -> 1257     picks = _picks_str_to_idx(
#    1258         info,
#    1259         picks,
#    1260         exclude,
#    1261         with_ref_meg,
#    1262         return_kind,
#    1263         extra_repr,
#    1264         allow_empty,
#    1265         orig_picks,
#    1266     )
#    1267     if return_kind:
#    1268         picked_ch_type_or_generic = picks[1]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\mne\_fiff\pick.py:1394, in _picks_str_to_idx(info, picks, exclude, with_ref_meg, return_kind, extra_repr, allow_empty, orig_picks)
#    1392 if sum(any_found) == 0:
#    1393     if not allow_empty:
# -> 1394         raise ValueError(
#    1395             f"picks ({repr(orig_picks) + extra_repr}) could not be interpreted as "
#    1396             f'channel names (no channel "{bad_names}"), channel types (no type'
#    1397             f' "{bad_type}" present), or a generic type (just "all" or "data")'
#    1398         )
#    1399     picks = np.array([], int)
#    1400 elif sum(any_found) > 1:
#
# ValueError: picks ('Time') could not be interpreted as channel names (no channel "['Time']"), channel types (no type "Time" present), or a generic type (just "all" or "data")

# %%
windows_df = pd.concat(windows, ignore_index=True)
windows_df_0 = windows_df[windows_df['idx']==0]
windows_df_0

# %%
mask = merged_df[
